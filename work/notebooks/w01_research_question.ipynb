# %% [markdown]
# <a href="https://colab.research.google.com/github/vangaricharmi-cmyk/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print(df.head())
print("\n")
print(df.describe(include="all"))
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vangaricharmi-cmyk/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane: Refresh / Content Opportunity Scoring
#
# I selected Lane 2 because it focuses on identifying content that should be refreshed or improved based on its performance. This project helps prioritize which web pages need attention first using data. I chose this lane because it is practical, beginner-friendly, and demonstrates how machine learning can support better decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Decision, Action, and Cost of a Wrong Call
#
# This project helps decide which web pages should be refreshed or improved first based on their performance data. The content or SEO team will use these recommendations to prioritize their work. If the recommendation is incorrect, time and resources may be wasted on low-priority pages, while important pages that need improvement could be overlooked, reducing overall website performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The dataset contains **30,000 pages** with **44 features** describing content performance. The average trend percentage is approximately **-4.79%**, indicating that many pages are experiencing declining performance. The dataset also includes **5 position tiers** and **4 impression tiers**, making it suitable for prioritizing content refresh opportunities.

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nPosition Tier Counts:")
print(df["position_tier"].value_counts())

print("\nImpression Tier Counts:")
print(df["impression_tier"].value_counts())
# Out:
# Rows: 30000
# Columns: 44
#
# Position Tier Counts:
# position_tier
# page_1      11814
# striking     7304
# page_3_5     7242
# top_3        2321
# deep         1319
# Name: count, dtype: int64
#
# Impression Tier Counts:
# impression_tier
# low          11248
# moderate     10469
# good          7205
# excellent     1078
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project identifies patterns in website content performance and helps prioritize pages that may need refreshing. It supports decision-making based on historical data but does not prove that refreshing a page will improve rankings or traffic. The model provides recommendations rather than guaranteed outcomes, and final decisions should be made by the content or SEO team.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
